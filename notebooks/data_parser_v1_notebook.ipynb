# %% [markdown]
# # v1

# %%
from pathlib import Path

TESTFILE = Path(r"C:\Users\utrfh\WS22-23 (MA) Masterarbeit\Measurements\BG - Package loss\230929d Delock\data\BG230929d_13-1_Delock_0dB_30-8_65ns_60mV_100_readout.01.bin")
TESTFILE = Path(r"C:\Users\utrfh\WS22-23 (MA) Masterarbeit\RADC_testData\2023-03-21_BoxcarWidth_tests\radc.3.bin")

# %%
import data_parser
data_parser.init("v1")
from data_parser import struct_conversion, data_io, plotting
# Out:
# Imported struct_conversion v1

# %%
datafile.format
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\utrfh\WS22-23 (MA) Masterarbeit\Codes\radc-processor\notebooks\data_parser_v1_notebook.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/utrfh/WS22-23%20%28MA%29%20Masterarbeit/Codes/radc-processor/notebooks/data_parser_v1_notebook.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> datafile.format
#
# NameError: name 'datafile' is not defined

# %%
file = TESTFILE
datafile = struct_conversion.DataFile(file, tracelength=700)
df = data_io.datafile_to_df(datafile)
df
# Out:
# (b'T', 1, b'\x00\x00', 0, 0, 0, b'\xc3>\x00', 0, 0, 0, 16357, 16356, 16355, 16356, 16356, 16357, 16356, 16355, 16354, 16355, 16356, 16355, 16355, 16355, 16356, 16356, 16356, 16354, 16355, 16356, 16356, 16356, 16358, 16356, 16356, 16354, 16356, 16355, 16356, 16357, 16356, 16356, 16357, 16355, 16356, 16354, 16354, 16356, 16357, 16358, 16357, 16358, 16357, 16356, 16357, 16355, 16352, 16353, 16353, 16354, 16354, 16356, 16356, 16356, 16357, 16356, 16357, 16354, 16352, 16353, 16353, 16352, 16355, 16356, 16359, 16357, 16356, 16356, 16358, 16355, 16355, 16357, 16355, 16356, 16356, 16355, 16355, 16355, 16355, 16357, 16356, 16355, 16356, 16358, 16356, 16356, 16356, 16355, 16355, 16354, 16357, 16355, 16355, 16357, 16357, 16356, 16356, 16353, 16354, 16355, 16355, 16355, 16356, 16354, 16354, 16355, 16355, 16354, 16355, 16356, 16356, 16354, 16354, 16355, 16354, 16356, 16356, 16356, 16355, 16358, 16358, 16358, 16359, 16357, 16357, 16358, 16356, 16356, 16356, 16357, 16356, 16357, 16356, 16355, 16355
# ...
