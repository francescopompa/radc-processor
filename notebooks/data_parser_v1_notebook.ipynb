# %% [markdown]
# # v1

# %%
from pathlib import Path

TESTFILE = Path(r"C:\Users\utrfh\WS22-23 (MA) Masterarbeit\RADC_testData\2023-09-30\2023-09-30_21-40-46_readout.01.bin")

# %%
import data_parser
data_parser.init("v1")
from data_parser import struct_conversion, data_io, plotting

# %%
file = TESTFILE
datafile = struct_conversion.DataFile(file, tracelength=64)
df = data_io.datafile_to_df(datafile)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\utrfh\WS22-23 (MA) Masterarbeit\Codes\radc-processor\notebooks\data_parser_v1_notebook.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/utrfh/WS22-23%20%28MA%29%20Masterarbeit/Codes/radc-processor/notebooks/data_parser_v1_notebook.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> file = TESTFILE
#       <a href='vscode-notebook-cell:/c%3A/Users/utrfh/WS22-23%20%28MA%29%20Masterarbeit/Codes/radc-processor/notebooks/data_parser_v1_notebook.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> datafile = struct_conversion.DataFile(file, tracelength=64)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/utrfh/WS22-23%20%28MA%29%20Masterarbeit/Codes/radc-processor/notebooks/data_parser_v1_notebook.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> df = data_io.datafile_to_df(datafile)
#
# ...
